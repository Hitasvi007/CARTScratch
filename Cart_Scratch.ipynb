# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
wine_data = pd.read_csv(url, sep=';')

print(wine_data.head())
print(wine_data.dtypes)
print(wine_data.isnull().sum())

wine_data = wine_data.dropna()

feature_columns = wine_data.columns[:-1]
X = wine_data[feature_columns].astype(float).values

y = (wine_data['quality'] >= 6).astype(int).values


X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)
train_data = np.hstack((X_train, y_train.reshape(-1, 1)))
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# CART

# %%
def gini_index(groups, classes):
    n_instances = sum([len(group) for group in groups])
    gini = 0.0
    for group in groups:
        size = len(group)
        if size == 0:
            continue
        score = 0.0
        for class_val in classes:
            proportion = [row[-1] for row in group].count(class_val) / float(size)
            score += proportion * proportion
        gini += (1.0 - score) * (size / n_instances)
    return gini

# %%
def test_split(index, value, dataset):
    left, right = list(), list()
    for row in dataset:
        if row[index] < value:
            left.append(row)
        else:
            right.append(row)
    return left, right
def to_terminal(group):
    outcomes = [row[-1] for row in group]
    return max(set(outcomes), key=outcomes.count)

# %%
def split(node, max_depth, min_size, depth):
    left, right = node['groups']
    del(node['groups'])
    if not left or not right:
        node['left'] = node['right'] = to_terminal(left + right)
        return
    if depth >= max_depth:
        node['left'], node['right'] = to_terminal(left), to_terminal(right)
        return
    if len(left) <= min_size:
        node['left'] = to_terminal(left)
    else:
        node['left'] = get_split(left, max_depth, min_size, depth + 1)
        split(node['left'], max_depth, min_size, depth + 1)
    if len(right) <= min_size:
        node['right'] = to_terminal(right)
    else:
        node['right'] = get_split(right, max_depth, min_size, depth + 1)
        split(node['right'], max_depth, min_size, depth + 1)

# %%
def get_split(dataset, max_depth, min_size, depth=1):
    class_values = list(set(row[-1] for row in dataset))
    b_index, b_value, b_score, b_groups = 999, 999, 999, None
    for index in range(len(dataset[0])-1):
        for row in dataset:
            groups = test_split(index, row[index], dataset)
            gini = gini_index(groups, class_values)
            print(f"Testing split: Feature index {index}, Feature value {row[index]}, Gini = {gini:.4f}")
            if gini < b_score:
                b_index, b_value, b_score, b_groups = index, row[index], gini, groups
    print(f"\nBest split: Feature index {b_index}, Feature value {b_value}, Gini = {b_score:.4f}\n")
    return {'index': b_index, 'value': b_value, 'groups': b_groups}

# %%
def build_tree(train, max_depth, min_size):
    root = get_split(train, max_depth, min_size)
    split(root, max_depth, min_size, 1)
    return root

# %%
def predict(node, row):
    if row[node['index']] < node['value']:
        if isinstance(node['left'], dict):
            return predict(node['left'], row)
        else:
            return node['left']
    else:
        if isinstance(node['right'], dict):
            return predict(node['right'], row)
        else:
            return node['right']

# %%
cart_tree = build_tree(train_data, max_depth=5, min_size=10)
cart_predictions = [predict(cart_tree, row) for row in X_test]
cart_accuracy = accuracy_score(y_test, cart_predictions)
# Out:
# Streaming output truncated to the last 5000 lines.
# Testing split: Feature index 7, Feature value 0.9951, Gini = 0.2096
# Testing split: Feature index 7, Feature value 0.99528, Gini = 0.2099
# Testing split: Feature index 7, Feature value 0.99397, Gini = 0.2112
# Testing split: Feature index 7, Feature value 0.99552, Gini = 0.2105
# Testing split: Feature index 7, Feature value 0.9976, Gini = 0.2101
# Testing split: Feature index 7, Feature value 0.9947, Gini = 0.2110
# Testing split: Feature index 7, Feature value 0.999, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.99524, Gini = 0.2102
# Testing split: Feature index 7, Feature value 0.99674, Gini = 0.2094
# Testing split: Feature index 7, Feature value 0.99508, Gini = 0.2098
# Testing split: Feature index 7, Feature value 0.9956, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.9934, Gini = 0.2099
# Testing split: Feature index 7, Feature value 0.99652, Gini = 0.2076
# Testing split: Feature index 7, Feature value 0.9976, Gini = 0.2101
# Testing split: Feature index 7, Feature value 1.0014, Gini = 0.2076
# Testing split: Feature index 7, Feature value 0.99562, Gini = 0.2104
# Testing split: Feature index 7, Feature value 0.9924, Gini = 0.2110
# Testing split: Feature index 7, Feature value 0.99565, Gini = 0.2103
# Testing split: Feature index 7, Feature value 0.9951, Gini = 0.2096
# Testing split: Feature index 7, Feature value 0.9988, Gini = 0.2114
# Testing split: Feature index 7, Feature value 0.99738, Gini = 0.2107
# Testing split: Feature index 7, Feature value 0.99546, Gini = 0.2107
# Testing split: Feature index 7, Feature value 0.99652, Gini = 0.2076
# Testing split: Feature index 7, Feature value 0.99534, Gini = 0.2097
# Testing split: Feature index 7, Feature value 0.99388, Gini = 0.2114
# Testing split: Feature index 7, Feature value 0.99516, Gini = 0.2088
# Testing split: Feature index 7, Feature value 0.9916, Gini = 0.2115
# Testing split: Feature index 7, Feature value 0.99627, Gini = 0.2070
# Testing split: Feature index 7, Feature value 0.9947, Gini = 0.2110
# Testing split: Feature index 7, Feature value 0.9993, Gini = 0.2097
# Testing split: Feature index 7, Feature value 0.9992, Gini = 0.2100
# Testing split: Feature index 7, Feature value 0.99684, Gini = 0.2103
# Testing split: Feature index 7, Feature value 0.9996, Gini = 0.2080
# Testing split: Feature index 7, Feature value 0.99598, Gini = 0.2086
# Testing split: Feature index 7, Feature value 0.9953, Gini = 0.2099
# Testing split: Feature index 7, Feature value 0.99516, Gini = 0.2088
# Testing split: Feature index 7, Feature value 0.9937, Gini = 0.2088
# Testing split: Feature index 7, Feature value 0.99544, Gini = 0.2107
# Testing split: Feature index 7, Feature value 0.99586, Gini = 0.2091
# Testing split: Feature index 7, Feature value 0.9978, Gini = 0.2101
# Testing split: Feature index 7, Feature value 0.9964, Gini = 0.2074
# Testing split: Feature index 7, Feature value 0.9963, Gini = 0.2078
# Testing split: Feature index 7, Feature value 0.99645, Gini = 0.2070
# Testing split: Feature index 7, Feature value 0.99604, Gini = 0.2090
# Testing split: Feature index 7, Feature value 0.99396, Gini = 0.2113
# Testing split: Feature index 7, Feature value 0.99519, Gini = 0.2099
# Testing split: Feature index 7, Feature value 0.99438, Gini = 0.2118
# Testing split: Feature index 7, Feature value 0.9955, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.9962, Gini = 0.2082
# Testing split: Feature index 7, Feature value 0.9962, Gini = 0.2082
# Testing split: Feature index 7, Feature value 0.99724, Gini = 0.2109
# Testing split: Feature index 7, Feature value 0.99182, Gini = 0.2113
# Testing split: Feature index 7, Feature value 0.99633, Gini = 0.2071
# Testing split: Feature index 7, Feature value 0.9976, Gini = 0.2101
# Testing split: Feature index 7, Feature value 0.99516, Gini = 0.2088
# Testing split: Feature index 7, Feature value 0.9934, Gini = 0.2099
# Testing split: Feature index 7, Feature value 0.99704, Gini = 0.2108
# Testing split: Feature index 7, Feature value 0.99456, Gini = 0.2113
# Testing split: Feature index 7, Feature value 0.99386, Gini = 0.2115
# Testing split: Feature index 7, Feature value 0.9969, Gini = 0.2101
# Testing split: Feature index 7, Feature value 0.99572, Gini = 0.2100
# Testing split: Feature index 7, Feature value 0.999, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.9973, Gini = 0.2113
# Testing split: Feature index 7, Feature value 0.99708, Gini = 0.2107
# Testing split: Feature index 7, Feature value 0.99585, Gini = 0.2093
# Testing split: Feature index 7, Feature value 0.9972, Gini = 0.2105
# Testing split: Feature index 7, Feature value 0.99818, Gini = 0.2087
# Testing split: Feature index 7, Feature value 0.99235, Gini = 0.2111
# Testing split: Feature index 7, Feature value 0.99514, Gini = 0.2093
# Testing split: Feature index 7, Feature value 1.0014, Gini = 0.2076
# Testing split: Feature index 7, Feature value 1.0032, Gini = 0.2119
# Testing split: Feature index 7, Feature value 0.9966, Gini = 0.2067
# Testing split: Feature index 7, Feature value 0.99374, Gini = 0.2112
# Testing split: Feature index 7, Feature value 0.99374, Gini = 0.2112
# Testing split: Feature index 7, Feature value 0.99722, Gini = 0.2102
# Testing split: Feature index 7, Feature value 0.99182, Gini = 0.2113
# Testing split: Feature index 7, Feature value 1.00315, Gini = 0.2061
# Testing split: Feature index 7, Feature value 0.9976, Gini = 0.2101
# Testing split: Feature index 7, Feature value 0.9963, Gini = 0.2078
# Testing split: Feature index 7, Feature value 0.99639, Gini = 0.2075
# Testing split: Feature index 7, Feature value 0.99533, Gini = 0.2098
# Testing split: Feature index 7, Feature value 0.9989, Gini = 0.2108
# Testing split: Feature index 7, Feature value 0.9956, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.99612, Gini = 0.2089
# Testing split: Feature index 7, Feature value 0.9917, Gini = 0.2114
# Testing split: Feature index 7, Feature value 0.99538, Gini = 0.2089
# Testing split: Feature index 7, Feature value 0.9988, Gini = 0.2114
# Testing split: Feature index 7, Feature value 0.99378, Gini = 0.2116
# Testing split: Feature index 7, Feature value 0.9937, Gini = 0.2088
# Testing split: Feature index 7, Feature value 0.9949, Gini = 0.2099
# Testing split: Feature index 7, Feature value 0.9902, Gini = 0.2120
# Testing split: Feature index 7, Feature value 0.9959, Gini = 0.2088
# Testing split: Feature index 7, Feature value 1.0002, Gini = 0.2109
# Testing split: Feature index 7, Feature value 0.99294, Gini = 0.2102
# Testing split: Feature index 7, Feature value 0.9936, Gini = 0.2091
# Testing split: Feature index 7, Feature value 0.99728, Gini = 0.2107
# Testing split: Feature index 7, Feature value 0.9962, Gini = 0.2082
# Testing split: Feature index 7, Feature value 0.9986, Gini = 0.2117
# Testing split: Feature index 7, Feature value 0.99495, Gini = 0.2097
# Testing split: Feature index 7, Feature value 0.99566, Gini = 0.2102
# Testing split: Feature index 7, Feature value 0.99818, Gini = 0.2087
# Testing split: Feature index 7, Feature value 0.9947, Gini = 0.2110
# Testing split: Feature index 7, Feature value 0.9994, Gini = 0.2091
# Testing split: Feature index 7, Feature value 0.9975, Gini = 0.2102
# Testing split: Feature index 7, Feature value 0.99518, Gini = 0.2101
# Testing split: Feature index 7, Feature value 0.99557, Gini = 0.2102
# Testing split: Feature index 7, Feature value 0.99502, Gini = 0.2100
# Testing split: Feature index 7, Feature value 0.9988, Gini = 0.2114
# Testing split: Feature index 7, Feature value 0.99479, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.99292, Gini = 0.2103
# Testing split: Feature index 7, Feature value 0.9956, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.997, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.9966, Gini = 0.2067
# Testing split: Feature index 7, Feature value 0.995, Gini = 0.2094
# Testing split: Feature index 7, Feature value 0.9962, Gini = 0.2082
# Testing split: Feature index 7, Feature value 0.99692, Gini = 0.2108
# Testing split: Feature index 7, Feature value 1.0002, Gini = 0.2109
# Testing split: Feature index 7, Feature value 0.99656, Gini = 0.2071
# Testing split: Feature index 7, Feature value 0.9908, Gini = 0.2119
# Testing split: Feature index 7, Feature value 0.9986, Gini = 0.2117
# Testing split: Feature index 7, Feature value 0.99512, Gini = 0.2094
# Testing split: Feature index 7, Feature value 0.99828, Gini = 0.2107
# Testing split: Feature index 7, Feature value 0.9988, Gini = 0.2114
# Testing split: Feature index 7, Feature value 0.99552, Gini = 0.2105
# Testing split: Feature index 7, Feature value 0.99534, Gini = 0.2097
# Testing split: Feature index 7, Feature value 0.9962, Gini = 0.2082
# Testing split: Feature index 7, Feature value 0.9999, Gini = 0.2079
# Testing split: Feature index 7, Feature value 0.995, Gini = 0.2094
# Testing split: Feature index 7, Feature value 0.99492, Gini = 0.2098
# Testing split: Feature index 7, Feature value 0.99157, Gini = 0.2116
# Testing split: Feature index 7, Feature value 0.99652, Gini = 0.2076
# Testing split: Feature index 7, Feature value 0.99362, Gini = 0.2090
# Testing split: Feature index 7, Feature value 0.9927, Gini = 0.2105
# Testing split: Feature index 7, Feature value 0.99557, Gini = 0.2102
# Testing split: Feature index 7, Feature value 0.99522, Gini = 0.2104
# Testing split: Feature index 7, Feature value 0.99538, Gini = 0.2089
# Testing split: Feature index 7, Feature value 0.996, Gini = 0.2082
# Testing split: Feature index 7, Feature value 0.9968, Gini = 0.2088
# Testing split: Feature index 7, Feature value 0.99974, Gini = 0.2093
# Testing split: Feature index 7, Feature value 0.99498, Gini = 0.2095
# Testing split: Feature index 7, Feature value 0.99666, Gini = 0.2096
# Testing split: Feature index 7, Feature value 0.9996, Gini = 0.2080
# Testing split: Feature index 7, Feature value 0.99451, Gini = 0.2113
# Testing split: Feature index 7, Feature value 0.99426, Gini = 0.2119
# Testing split: Feature index 7, Feature value 0.9944, Gini = 0.2117
# Testing split: Feature index 7, Feature value 0.99576, Gini = 0.2096
# Testing split: Feature index 7, Feature value 0.99534, Gini = 0.2097
# Testing split: Feature index 7, Feature value 0.9998, Gini = 0.2089
# Testing split: Feature index 7, Feature value 0.99444, Gini = 0.2116
# Testing split: Feature index 7, Feature value 0.99483, Gini = 0.2102
# Testing split: Feature index 7, Feature value 0.99378, Gini = 0.2116
# Testing split: Feature index 7, Feature value 0.99633, Gini = 0.2071
# Testing split: Feature index 7, Feature value 0.99414, Gini = 0.2119
# Testing split: Feature index 7, Feature value 0.99646, Gini = 0.2081
# Testing split: Feature index 7, Feature value 0.99504, Gini = 0.2099
# Testing split: Feature index 7, Feature value 0.99495, Gini = 0.2097
# Testing split: Feature index 7, Feature value 0.99599, Gini = 0.2085
# Testing split: Feature index 7, Feature value 0.9986, Gini = 0.2117
# Testing split: Feature index 7, Feature value 0.99467, Gini = 0.2110
# Testing split: Feature index 7, Feature value 0.9948, Gini = 0.2105
# Testing split: Feature index 7, Feature value 0.9965, Gini = 0.2078
# Testing split: Feature index 7, Feature value 0.9994, Gini = 0.2091
# Testing split: Feature index 7, Feature value 0.999, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.9979, Gini = 0.2095
# Testing split: Feature index 7, Feature value 0.99627, Gini = 0.2070
# Testing split: Feature index 7, Feature value 0.997, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.99414, Gini = 0.2119
# Testing split: Feature index 7, Feature value 1.0021, Gini = 0.2082
# Testing split: Feature index 7, Feature value 0.99736, Gini = 0.2110
# Testing split: Feature index 7, Feature value 0.99356, Gini = 0.2094
# Testing split: Feature index 7, Feature value 0.9933, Gini = 0.2100
# Testing split: Feature index 7, Feature value 0.99536, Gini = 0.2091
# Testing split: Feature index 7, Feature value 0.997, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.99622, Gini = 0.2072
# Testing split: Feature index 7, Feature value 0.99473, Gini = 0.2107
# Testing split: Feature index 7, Feature value 0.99394, Gini = 0.2114
# Testing split: Feature index 7, Feature value 1.0004, Gini = 0.2093
# Testing split: Feature index 7, Feature value 0.9948, Gini = 0.2105
# Testing split: Feature index 7, Feature value 0.99724, Gini = 0.2109
# Testing split: Feature index 7, Feature value 0.99514, Gini = 0.2093
# Testing split: Feature index 7, Feature value 0.99572, Gini = 0.2100
# Testing split: Feature index 7, Feature value 0.9962, Gini = 0.2082
# Testing split: Feature index 7, Feature value 0.99552, Gini = 0.2105
# Testing split: Feature index 7, Feature value 0.99354, Gini = 0.2095
# Testing split: Feature index 7, Feature value 0.99649, Gini = 0.2080
# Testing split: Feature index 7, Feature value 0.99736, Gini = 0.2110
# Testing split: Feature index 7, Feature value 0.99557, Gini = 0.2102
# Testing split: Feature index 7, Feature value 0.99439, Gini = 0.2117
# Testing split: Feature index 7, Feature value 0.9974, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.99554, Gini = 0.2102
# Testing split: Feature index 7, Feature value 0.99314, Gini = 0.2101
# Testing split: Feature index 7, Feature value 0.9984, Gini = 0.2118
# Testing split: Feature index 7, Feature value 0.9973, Gini = 0.2113
# Testing split: Feature index 7, Feature value 0.99524, Gini = 0.2102
# Testing split: Feature index 7, Feature value 0.9946, Gini = 0.2111
# Testing split: Feature index 7, Feature value 0.99438, Gini = 0.2118
# Testing split: Feature index 7, Feature value 0.99484, Gini = 0.2101
# Testing split: Feature index 7, Feature value 0.99586, Gini = 0.2091
# Testing split: Feature index 7, Feature value 0.99356, Gini = 0.2094
# Testing split: Feature index 7, Feature value 0.9952, Gini = 0.2099
# Testing split: Feature index 7, Feature value 0.99514, Gini = 0.2093
# Testing split: Feature index 7, Feature value 0.99828, Gini = 0.2107
# Testing split: Feature index 7, Feature value 1.0018, Gini = 0.2044
# Testing split: Feature index 7, Feature value 0.99376, Gini = 0.2117
# Testing split: Feature index 7, Feature value 0.99402, Gini = 0.2112
# Testing split: Feature index 7, Feature value 0.997, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.99408, Gini = 0.2117
# Testing split: Feature index 7, Feature value 1.0002, Gini = 0.2109
# Testing split: Feature index 7, Feature value 0.99356, Gini = 0.2094
# Testing split: Feature index 7, Feature value 0.99448, Gini = 0.2114
# Testing split: Feature index 7, Feature value 0.99516, Gini = 0.2088
# Testing split: Feature index 7, Feature value 0.9972, Gini = 0.2105
# Testing split: Feature index 7, Feature value 0.99745, Gini = 0.2104
# Testing split: Feature index 7, Feature value 0.9964, Gini = 0.2074
# Testing split: Feature index 7, Feature value 0.99588, Gini = 0.2089
# Testing split: Feature index 7, Feature value 0.99536, Gini = 0.2091
# Testing split: Feature index 7, Feature value 0.99614, Gini = 0.2088
# Testing split: Feature index 7, Feature value 0.99676, Gini = 0.2091
# Testing split: Feature index 7, Feature value 0.99352, Gini = 0.2096
# Testing split: Feature index 7, Feature value 0.99438, Gini = 0.2118
# Testing split: Feature index 7, Feature value 0.99686, Gini = 0.2102
# Testing split: Feature index 7, Feature value 0.99258, Gini = 0.2107
# Testing split: Feature index 7, Feature value 0.99534, Gini = 0.2097
# Testing split: Feature index 7, Feature value 0.99674, Gini = 0.2094
# Testing split: Feature index 7, Feature value 0.9943, Gini = 0.2119
# Testing split: Feature index 7, Feature value 0.997, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.99615, Gini = 0.2086
# Testing split: Feature index 7, Feature value 0.99566, Gini = 0.2102
# Testing split: Feature index 7, Feature value 0.99939, Gini = 0.2095
# Testing split: Feature index 7, Feature value 0.99538, Gini = 0.2089
# Testing split: Feature index 7, Feature value 0.99638, Gini = 0.2080
# Testing split: Feature index 7, Feature value 0.9998, Gini = 0.2089
# Testing split: Feature index 7, Feature value 0.99658, Gini = 0.2069
# Testing split: Feature index 7, Feature value 0.99617, Gini = 0.2085
# Testing split: Feature index 7, Feature value 0.99577, Gini = 0.2095
# Testing split: Feature index 7, Feature value 0.99859, Gini = 0.2118
# Testing split: Feature index 7, Feature value 0.99501, Gini = 0.2091
# Testing split: Feature index 7, Feature value 0.998, Gini = 0.2093
# Testing split: Feature index 7, Feature value 0.99732, Gini = 0.2111
# Testing split: Feature index 7, Feature value 0.9954, Gini = 0.2110
# Testing split: Feature index 7, Feature value 0.99518, Gini = 0.2101
# Testing split: Feature index 7, Feature value 1.0001, Gini = 0.2098
# Testing split: Feature index 7, Feature value 0.99486, Gini = 0.2100
# Testing split: Feature index 7, Feature value 0.99676, Gini = 0.2091
# Testing split: Feature index 7, Feature value 0.99523, Gini = 0.2103
# Testing split: Feature index 7, Feature value 0.9924, Gini = 0.2110
# Testing split: Feature index 7, Feature value 0.9952, Gini = 0.2099
# Testing split: Feature index 7, Feature value 0.9924, Gini = 0.2110
# Testing split: Feature index 7, Feature value 1.00315, Gini = 0.2061
# Testing split: Feature index 7, Feature value 0.995, Gini = 0.2094
# Testing split: Feature index 7, Feature value 0.99814, Gini = 0.2089
# Testing split: Feature index 7, Feature value 0.996, Gini = 0.2082
# Testing split: Feature index 7, Feature value 0.9958, Gini = 0.2094
# Testing split: Feature index 7, Feature value 0.9963, Gini = 0.2078
# Testing split: Feature index 7, Feature value 0.9988, Gini = 0.2114
# Testing split: Feature index 7, Feature value 0.99472, Gini = 0.2107
# Testing split: Feature index 7, Feature value 0.9986, Gini = 0.2117
# Testing split: Feature index 7, Feature value 1.0006, Gini = 0.2085
# Testing split: Feature index 7, Feature value 0.99638, Gini = 0.2080
# Testing split: Feature index 7, Feature value 1.0003, Gini = 0.2098
# Testing split: Feature index 7, Feature value 0.9966, Gini = 0.2067
# Testing split: Feature index 7, Feature value 0.99376, Gini = 0.2117
# Testing split: Feature index 7, Feature value 0.99538, Gini = 0.2089
# Testing split: Feature index 7, Feature value 0.99619, Gini = 0.2084
# Testing split: Feature index 7, Feature value 0.99572, Gini = 0.2100
# Testing split: Feature index 7, Feature value 0.99543, Gini = 0.2109
# Testing split: Feature index 7, Feature value 0.9962, Gini = 0.2082
# Testing split: Feature index 7, Feature value 0.9967, Gini = 0.2095
# Testing split: Feature index 7, Feature value 0.99543, Gini = 0.2109
# Testing split: Feature index 7, Feature value 0.99774, Gini = 0.2102
# Testing split: Feature index 7, Feature value 0.9941, Gini = 0.2116
# Testing split: Feature index 7, Feature value 0.9948, Gini = 0.2105
# Testing split: Feature index 7, Feature value 0.99736, Gini = 0.2110
# Testing split: Feature index 7, Feature value 0.9974, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.9929, Gini = 0.2104
# Testing split: Feature index 7, Feature value 0.99458, Gini = 0.2112
# Testing split: Feature index 7, Feature value 0.9981, Gini = 0.2091
# Testing split: Feature index 7, Feature value 0.9968, Gini = 0.2088
# Testing split: Feature index 7, Feature value 0.99628, Gini = 0.2066
# Testing split: Feature index 7, Feature value 0.99526, Gini = 0.2100
# Testing split: Feature index 7, Feature value 0.99258, Gini = 0.2107
# Testing split: Feature index 7, Feature value 0.99514, Gini = 0.2093
# Testing split: Feature index 7, Feature value 0.9994, Gini = 0.2091
# Testing split: Feature index 7, Feature value 1.00012, Gini = 0.2112
# Testing split: Feature index 7, Feature value 0.9968, Gini = 0.2088
# Testing split: Feature index 7, Feature value 0.9971, Gini = 0.2106
# Testing split: Feature index 7, Feature value 0.99444, Gini = 0.2116
# Testing split: Feature index 7, Feature value 0.9978, Gini = 0.2101
# Testing split: Feature index 7, Feature value 0.9952, Gini = 0.2099
# Testing split: Feature index 7, Feature value 0.99444, Gini = 0.2116
# Testing split: Feature index 7, Feature value 0.9912, Gini = 0.2118
# Testing split: Feature index 7, Feature value 0.99516, Gini = 0.2088
# Testing split: Feature index 7, Feature value 0.9972, Gini = 0.2105
# Testing split: Feature index 7, Feature value 0.99638, Gini = 0.2080
# Testing split: Feature index 7, Feature value 0.99534, Gini = 0.2097
# Testing split: Feature index 7, Feature value 0.99444, Gini = 0.2116
# Testing split: Feature index 7, Feature value 0.99572, Gini = 0.2100
# Testing split: Feature index 7, Feature value 0.9963, Gini = 0.2078
# Testing split: Feature index 7, Feature value 0.99664, Gini = 0.2098
# Testing split: Feature index 7, Feature value 0.99509, Gini = 0.2097
# Testing split: Feature index 7, Feature value 0.99692, Gini = 0.2108
# Testing split: Feature index 7, Feature value 0.9976, Gini = 0.2101
# Testing split: Feature index 7, Feature value 0.99599, Gini = 0.2085
# Testing split: Feature index 8, Feature value 3.35, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.26, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.71, Gini = 0.2112
# Testing split: Feature index 8, Feature value 3.15, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.4, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.43, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.42, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.41, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.23, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.32, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.17, Gini = 0.2116
# Testing split: Feature index 8, Feature value 3.3, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.33, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.45, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.22, Gini = 0.2115
# Testing split: Feature index 8, Feature value 3.57, Gini = 0.2115
# Testing split: Feature index 8, Feature value 3.47, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.34, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.01, Gini = 0.2063
# Testing split: Feature index 8, Feature value 3.51, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.56, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.22, Gini = 0.2115
# Testing split: Feature index 8, Feature value 3.29, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.18, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.38, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.35, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.47, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.4, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.35, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.26, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.68, Gini = 0.2110
# Testing split: Feature index 8, Feature value 3.54, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.37, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.06, Gini = 0.2083
# Testing split: Feature index 8, Feature value 3.17, Gini = 0.2116
# Testing split: Feature index 8, Feature value 3.37, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.05, Gini = 0.2098
# Testing split: Feature index 8, Feature value 3.6, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.71, Gini = 0.2112
# Testing split: Feature index 8, Feature value 3.18, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.63, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.59, Gini = 0.2115
# Testing split: Feature index 8, Feature value 3.21, Gini = 0.2110
# Testing split: Feature index 8, Feature value 3.05, Gini = 0.2098
# Testing split: Feature index 8, Feature value 3.33, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.23, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.39, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.47, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.29, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.47, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.41, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.55, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.42, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.41, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.33, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.54, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.32, Gini = 0.2120
# Testing split: Feature index 8, Feature value 2.98, Gini = 0.2061
# Testing split: Feature index 8, Feature value 3.18, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.37, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.27, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.38, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.27, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.28, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.38, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.31, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.34, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.23, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.3, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.21, Gini = 0.2110
# Testing split: Feature index 8, Feature value 3.24, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.2, Gini = 0.2102
# Testing split: Feature index 8, Feature value 3.44, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.2, Gini = 0.2102
# Testing split: Feature index 8, Feature value 2.95, Gini = 0.2018
# Testing split: Feature index 8, Feature value 3.36, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.35, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.41, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.18, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.54, Gini = 0.2119
# Testing split: Feature index 8, Feature value 2.92, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.18, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.34, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.27, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.48, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.37, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.42, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.31, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.72, Gini = 0.2116
# Testing split: Feature index 8, Feature value 3.44, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.06, Gini = 0.2083
# Testing split: Feature index 8, Feature value 3.71, Gini = 0.2112
# Testing split: Feature index 8, Feature value 3.63, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.41, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.49, Gini = 0.2116
# Testing split: Feature index 8, Feature value 3.18, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.3, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.36, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.28, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.16, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.2, Gini = 0.2102
# Testing split: Feature index 8, Feature value 3.27, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.44, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.14, Gini = 0.2109
# Testing split: Feature index 8, Feature value 3.24, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.23, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.43, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.42, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.16, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.36, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.32, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.22, Gini = 0.2115
# Testing split: Feature index 8, Feature value 3.43, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.58, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.3, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.31, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.36, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.54, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.41, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.33, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.32, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.38, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.5, Gini = 0.2114
# Testing split: Feature index 8, Feature value 3.11, Gini = 0.2093
# Testing split: Feature index 8, Feature value 3.52, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.39, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.11, Gini = 0.2093
# Testing split: Feature index 8, Feature value 3.41, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.4, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.39, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.08, Gini = 0.2098
# Testing split: Feature index 8, Feature value 3.32, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.35, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.68, Gini = 0.2110
# Testing split: Feature index 8, Feature value 3.47, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.62, Gini = 0.2112
# Testing split: Feature index 8, Feature value 3.54, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.36, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.42, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.36, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.33, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.22, Gini = 0.2115
# Testing split: Feature index 8, Feature value 3.21, Gini = 0.2110
# Testing split: Feature index 8, Feature value 3.18, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.4, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.18, Gini = 0.2118
# Testing split: Feature index 8, Feature value 2.98, Gini = 0.2061
# Testing split: Feature index 8, Feature value 3.38, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.48, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.3, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.15, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.26, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.31, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.55, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.71, Gini = 0.2112
# Testing split: Feature index 8, Feature value 3.42, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.22, Gini = 0.2115
# Testing split: Feature index 8, Feature value 3.56, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.38, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.18, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.27, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.12, Gini = 0.2100
# Testing split: Feature index 8, Feature value 3.58, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.39, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.36, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.2, Gini = 0.2102
# Testing split: Feature index 8, Feature value 3.17, Gini = 0.2116
# Testing split: Feature index 8, Feature value 3.26, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.54, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.19, Gini = 0.2099
# Testing split: Feature index 8, Feature value 3.27, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.3, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.58, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.33, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.38, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.31, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.2, Gini = 0.2102
# Testing split: Feature index 8, Feature value 3.23, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.3, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.14, Gini = 0.2109
# Testing split: Feature index 8, Feature value 3.22, Gini = 0.2115
# Testing split: Feature index 8, Feature value 3.39, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.33, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.4, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.38, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.21, Gini = 0.2110
# Testing split: Feature index 8, Feature value 3.41, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.3, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.27, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.24, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.62, Gini = 0.2112
# Testing split: Feature index 8, Feature value 3.52, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.22, Gini = 0.2115
# Testing split: Feature index 8, Feature value 3.34, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.32, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.01, Gini = 0.2063
# Testing split: Feature index 8, Feature value 3.09, Gini = 0.2079
# Testing split: Feature index 8, Feature value 3.33, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.38, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.4, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.29, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.21, Gini = 0.2110
# Testing split: Feature index 8, Feature value 3.33, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.35, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.44, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.39, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.18, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.56, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.54, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.06, Gini = 0.2083
# Testing split: Feature index 8, Feature value 3.26, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.48, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.34, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.44, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.26, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.22, Gini = 0.2115
# Testing split: Feature index 8, Feature value 3.29, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.3, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.3, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.22, Gini = 0.2115
# Testing split: Feature index 8, Feature value 3.31, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.14, Gini = 0.2109
# Testing split: Feature index 8, Feature value 3.46, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.4, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.15, Gini = 0.2113
# Testing split: Feature index 8, Feature value 4.01, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.4, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.12, Gini = 0.2100
# Testing split: Feature index 8, Feature value 3.2, Gini = 0.2102
# Testing split: Feature index 8, Feature value 3.24, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.33, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.32, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.21, Gini = 0.2110
# Testing split: Feature index 8, Feature value 3.57, Gini = 0.2115
# Testing split: Feature index 8, Feature value 3.23, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.26, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.3, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.33, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.15, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.29, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.36, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.23, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.33, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.42, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.16, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.26, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.27, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.26, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.27, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.57, Gini = 0.2115
# Testing split: Feature index 8, Feature value 3.5, Gini = 0.2114
# Testing split: Feature index 8, Feature value 3.46, Gini = 0.2120
# Testing split: Feature index 8, Feature value 2.92, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.27, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.38, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.34, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.0, Gini = 0.2044
# Testing split: Feature index 8, Feature value 3.56, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.18, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.23, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.04, Gini = 0.2093
# Testing split: Feature index 8, Feature value 3.12, Gini = 0.2100
# Testing split: Feature index 8, Feature value 3.29, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.26, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.32, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.56, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.36, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.33, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.02, Gini = 0.2085
# Testing split: Feature index 8, Feature value 3.39, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.21, Gini = 0.2110
# Testing split: Feature index 8, Feature value 3.32, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.39, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.22, Gini = 0.2115
# Testing split: Feature index 8, Feature value 3.28, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.39, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.58, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.49, Gini = 0.2116
# Testing split: Feature index 8, Feature value 3.33, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.32, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.24, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.5, Gini = 0.2114
# Testing split: Feature index 8, Feature value 3.4, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.24, Gini = 0.2119
# Testing split: Feature index 8, Feature value 4.01, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.4, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.1, Gini = 0.2089
# Testing split: Feature index 8, Feature value 3.09, Gini = 0.2079
# Testing split: Feature index 8, Feature value 3.16, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.19, Gini = 0.2099
# Testing split: Feature index 8, Feature value 3.78, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.15, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.34, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.42, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.25, Gini = 0.2116
# Testing split: Feature index 8, Feature value 3.35, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.15, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.29, Gini = 0.2117
# Testing split: Feature index 8, Feature value 3.4, Gini = 0.2118
# Testing split: Feature index 8, Feature value 3.31, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.42, Gini = 0.2119
# Testing split: Feature index 8, Feature value 3.44, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.12, Gini = 0.2100
# Testing split: Feature index 8, Feature value 3.36, Gini = 0.2113
# Testing split: Feature index 8, Feature value 3.33, Gini = 0.2120
# Testing split: Feature index 8, Feature value 3.25, Gini = 0.2116
# Testing split: Feature index 8, Feature value 3.27, Gini = 0.2118
# Testing split: Feature index 9, Feature value 0.61, Gini = 0.2114
# Testing split: Feature index 9, Feature value 0.84, Gini = 0.2116
# Testing split: Feature index 9, Feature value 0.74, Gini = 0.2108
# Testing split: Feature index 9, Feature value 0.9, Gini = 0.2119
# Testing split: Feature index 9, Feature value 0.64, Gini = 0.2118
# Testing split: Feature index 9, Feature value 0.59, Gini = 0.2120
# Testing split: Feature index 9, Feature value 0.62, Gini = 0.2116
# Testing split: Feature index 9, Feature value 0.76, Gini = 0.2108
# Testing split: Feature index 9, Feature value 0.82, Gini = 0.2106
# Testing split: Feature index 9, Feature value 0.79, Gini = 0.2115
# Testing split: Feature index 9, Feature value 0.85, Gini = 0.2115
# Testing split: Feature index 9, Feature value 0.74, Gini = 0.2108
# Testing split: Feature index 9, Feature value 0.62, Gini = 0.2116
# Testing split: Feature index 9, Feature value 0.63, Gini = 0.2118
# Testing split: Feature index 9, Feature value 0.66, Gini = 0.2119
# Testing split: Feature index 9, Feature value 0.84, Gini = 0.2116
# Testing split: Feature index 9, Feature value 0.73, Gini = 0.2102
# Testing split: Feature index 9, Feature value 0.86, Gini = 0.2119
# Testing split: Feature index 9, Feature value 0.81, Gini = 0.2100
# Testing split: Feature index 9, Feature value 0.66, Gini = 0.2119
# Testing split: Feature index 9, Feature value 0.82, Gini = 0.2106
# Testing split: Feature index 9, Feature value 0.63, Gini = 0.2118
# Testing split: Feature index 9, Feature value 0.66, Gini = 0.2119
# Testing split: Feature index 9, Feature value 0.65, Gini = 0.2119
# Testing split: Feature index 9, Feature value 0.66, Gini = 0.2119
# Testing split: Feature index 9, Feature value 0.6, Gini = 0.2108
# Testing split: Feature index 9, Feature value 0.73, Gini = 0.2102
# Testing split: Feature index 9, Feature value 0.85, Gini = 0.2115
# Testing split: Feature index 9, Feature value 0.63, Gini = 0.2118
# Testing split: Feature index 9, Feature value 0.84, Gini = 0.2116
# Testing split: Feature index 9, Feature value 0.79, Gini = 0.2115
# Testing split: Feature index 9, Feature value 0.6, Gini = 0.2108
# Testing split: Feature index 9, Feature value 0.78, Gini = 0.2118
# Testing split: Feature index 9, Feature value 0.72, Gini = 0.2096
# Testing split: Feature index 9, Feature value 0.84, Gini = 0.2116
# Testing split: Feature index 9, Feature value 0.68, Gini = 0.2120
# Testing split: Feature index 9, Feature value 0.61, Gini = 0.2114
# Testing split: Feature index 9, Feature value 0.74, Gini = 0.2108
# Testing split: Feature index 9, Feature value 0.62, Gini = 0.2116
# Testing split: Feature index 9, Feature value 0.8, Gini = 0.2111
# Testing split: Feature index 9, Feature value 0.63, Gini = 0.2118
# Testing split: Feature index 9, Feature value 0.68, Gini = 0.2120
# Testing split: Feature index 9, Feature value 0.59, Gini = 0.2120
# Testing split: Feature index 9, Feature value 0.74, Gini = 0.2108
# Testing split: Feature index 9, Feature value 0.67, Gini = 0.2118
# Testing split: Feature index 9, Feature value 0.63, Gini = 0.2118
# Testing split: Feature index 9, Feature value 0.68, Gini = 0.2120
# Testing split: Feature index 9, Feature value 0.87, Gini = 0.2120
# Testing split: Feature index 9, Feature value 0.71, Gini = 0.2105
# Testing split: Feature index 9, Feature value 0.71, Gini = 0.2105
# Testing split: Feature index 9, Feature value 0.83, Gini = 0.2113
# Testing split: Feature index 9, Feature value 0.61, Gini = 0.2114
# Testing split: Feature index 9, Feature value 0.65, Gini = 0.2119
# Testing split: Feature index 9, Feature value 0.59, Gini = 0.2120
# Testing split: Feature index 9, Feature value 0.87, Gini = 0.2120
# Testing split: Feature index 9, Feature value 0.88, Gini = 0.2120
# Testing split: Feature index 9, Feature value 0.7, Gini = 0.2117
# Testing split: Feature index 9, Feature value 0.84, Gini = 0.2116
# Testing split: Feature index 9, Feature value 0.8, Gini = 0.2111
# Testing split: Feature index 9, Feature value 0.93, Gini = 0.2120
# Testing split: Feature index 9, Feature value 0.77, Gini = 0.2117
# Testing split: Feature index 9, Feature value 0.72, Gini = 0.2096
# Testing split: Feature index 9, Feature value 0.71, Gini = 0.2105
# Testing split: Feature index 9, Feature value 0.79, Gini = 0.2115
# Testing split: Feature index 9, Feature value 0.6, Gini = 0.2108
# Testing split: Feature index 9, Feature value 0.79, Gini = 0.2115
# Testing split: Feature index 9, Feature value 0.79, Gini = 0.2115
# Testing split: Feature index 9, Feature value 0.72, Gini = 0.2096
# Testing split: Feature index 9, Feature value 0.86, Gini = 0.2119
# Testing split: Feature index 9, Feature value 0.87, Gini = 0.2120
# Testing split: Feature index 9, Feature value 0.71, Gini = 0.2105
# Testing split: Feature index 9, Feature value 0.72, Gini = 0.2096
# Testing split: Feature index 9, Feature value 0.65, Gini = 0.2119
# Testing split: Feature index 9, Feature value 0.66, Gini = 0.2119
# Testing split: Feature index 9, Feature value 0.68, Gini = 0.2120
# Testing split: Feature index 9, Feature value 0.78, Gini = 0.2118
# Testing split: Feature index 9, Feature value 0.76, Gini = 0.2108
# Testing split: Feature index 9, Feature value 0.6, Gini = 0.2108
# Testing split: Feature index 9, Feature value 0.68, Gini = 0.2120
# Testing split: Feature index 9, Feature value 0.88, Gini = 0.2120
# Testing split: Feature index 9, Feature value 0.74, Gini = 0.2108
# Testing split: Feature index 9, Feature value 1.04, Gini = 0.2115
# Testing split: Feature index 9, Feature value 0.74, Gini = 0.2108
# Testing split: Feature index 9, Feature value 0.64, Gini = 0.2118
# Testing split: Feature index 9, Feature value 0.65, Gini = 0.2119
# Testing split: Feature index 9, Feature value 0.71, Gini = 0.2105
# Testing split: Feature index 9, Feature value 0.72, Gini = 0.2096
# Testing split: Feature index 9, Feature value 0.62, Gini = 0.2116
# Testing split: Feature index 9, Feature value 0.74, Gini = 0.2108
# Testing split: Feature index 9, Feature value 0.63, Gini = 0.2118
# Testing split: Feature index 9, Feature value 0.68, Gini = 0.2120
# Testing split: Feature index 9, Feature value 0.63, Gini = 0.2118
# Testing split: Feature index 9, Feature value 0.63, Gini = 0.2118
# Testing split: Feature index 9, Feature value 0.75, Gini = 0.2104
# Testing split: Feature index 9, Feature value 0.66, Gini = 0.2119
# Testing split: Feature index 9, Feature value 0.83, Gini = 0.2113
# Testing split: Feature index 9, Feature value 0.76, Gini = 0.2108
# Testing split: Feature index 9, Feature value 0.62, Gini = 0.2116
# Testing split: Feature index 9, Feature value 0.66, Gini = 0.2119
# Testing split: Feature index 9, Feature value 0.67, Gini = 0.2118
# Testing split: Feature index 9, Feature value 1.13, Gini = 0.2118
# Testing split: Feature index 9, Feature value 0.82, Gini = 0.2106
# Testing split: Feature index 9, Feature value 0.72, Gini = 0.2096
# Testing split: Feature index 9, Feature value 0.79, Gini = 0.2115
# Testing split: Feature index 9, Feature value 0.71, Gini = 0.2105
# ...
# Testing split: Feature index 6, Feature value 12.0, Gini = 0.3409
# Testing split: Feature index 6, Feature value 24.0, Gini = 0.3500
# Testing split: Feature index 6, Feature value 60.0, Gini = 0.3485
# Testing split: Feature index 6, Feature value 11.0, Gini = 0.3463
# Testing split: Feature index 6, Feature value 96.0, Gini = 0.3409
# Testing split: Feature index 6, Feature value 12.0, Gini = 0.3409
# Testing split: Feature index 6, Feature value 12.0, Gini = 0.3409
# Testing split: Feature index 6, Feature value 47.0, Gini = 0.3506
# Testing split: Feature index 6, Feature value 31.0, Gini = 0.3471
# Testing split: Feature index 6, Feature value 88.0, Gini = 0.3477
# Testing split: Feature index 6, Feature value 33.0, Gini = 0.3424
# Testing split: Feature index 6, Feature value 86.0, Gini = 0.3510
# Testing split: Feature index 6, Feature value 14.0, Gini = 0.3446
# Testing split: Feature index 7, Feature value 0.9994, Gini = 0.3349
# Testing split: Feature index 7, Feature value 1.001, Gini = 0.3409
# Testing split: Feature index 7, Feature value 0.9955, Gini = 0.2662
# Testing split: Feature index 7, Feature value 0.99582, Gini = 0.3393
# Testing split: Feature index 7, Feature value 0.99467, Gini = 0.3477
# Testing split: Feature index 7, Feature value 0.99551, Gini = 0.3015
# Testing split: Feature index 7, Feature value 0.99476, Gini = 0.3182
# Testing split: Feature index 7, Feature value 0.99525, Gini = 0.3134
# Testing split: Feature index 7, Feature value 0.99577, Gini = 0.3326
# Testing split: Feature index 7, Feature value 0.9964, Gini = 0.3125
# Testing split: Feature index 7, Feature value 0.99437, Gini = 0.3364
# Testing split: Feature index 7, Feature value 0.9955, Gini = 0.2662
# Testing split: Feature index 7, Feature value 0.99592, Gini = 0.3030
# Testing split: Feature index 7, Feature value 0.9934, Gini = 0.3512
# Testing split: Feature index 7, Feature value 0.9964, Gini = 0.3125
# Testing split: Feature index 7, Feature value 0.99551, Gini = 0.3015
# Testing split: Feature index 7, Feature value 0.99572, Gini = 0.3242
# Testing split: Feature index 7, Feature value 0.9948, Gini = 0.3337
# Testing split: Feature index 7, Feature value 0.99357, Gini = 0.3463
# Testing split: Feature index 7, Feature value 0.99488, Gini = 0.3428
# Testing split: Feature index 7, Feature value 1.001, Gini = 0.3409
# Testing split: Feature index 7, Feature value 0.9966, Gini = 0.3283
# Testing split: Feature index 8, Feature value 3.44, Gini = 0.3283
# Testing split: Feature index 8, Feature value 3.41, Gini = 0.3409
# Testing split: Feature index 8, Feature value 3.36, Gini = 0.3512
# Testing split: Feature index 8, Feature value 3.53, Gini = 0.3512
# Testing split: Feature index 8, Feature value 3.5, Gini = 0.3209
# Testing split: Feature index 8, Feature value 3.56, Gini = 0.3506
# Testing split: Feature index 8, Feature value 3.5, Gini = 0.3209
# Testing split: Feature index 8, Feature value 3.51, Gini = 0.3446
# Testing split: Feature index 8, Feature value 3.53, Gini = 0.3512
# Testing split: Feature index 8, Feature value 3.54, Gini = 0.3512
# Testing split: Feature index 8, Feature value 3.59, Gini = 0.3337
# Testing split: Feature index 8, Feature value 3.36, Gini = 0.3512
# Testing split: Feature index 8, Feature value 3.53, Gini = 0.3512
# Testing split: Feature index 8, Feature value 3.74, Gini = 0.3463
# Testing split: Feature index 8, Feature value 3.53, Gini = 0.3512
# Testing split: Feature index 8, Feature value 3.56, Gini = 0.3506
# Testing split: Feature index 8, Feature value 3.58, Gini = 0.3428
# Testing split: Feature index 8, Feature value 3.51, Gini = 0.3446
# Testing split: Feature index 8, Feature value 3.66, Gini = 0.3364
# Testing split: Feature index 8, Feature value 3.6, Gini = 0.3182
# Testing split: Feature index 8, Feature value 3.43, Gini = 0.3349
# Testing split: Feature index 8, Feature value 3.63, Gini = 0.3477
# Testing split: Feature index 9, Feature value 0.52, Gini = 0.3471
# Testing split: Feature index 9, Feature value 0.67, Gini = 0.3463
# Testing split: Feature index 9, Feature value 0.44, Gini = 0.3477
# Testing split: Feature index 9, Feature value 0.58, Gini = 0.3134
# Testing split: Feature index 9, Feature value 0.63, Gini = 0.3510
# Testing split: Feature index 9, Feature value 0.51, Gini = 0.3512
# Testing split: Feature index 9, Feature value 0.4, Gini = 0.3512
# Testing split: Feature index 9, Feature value 0.43, Gini = 0.3463
# Testing split: Feature index 9, Feature value 0.54, Gini = 0.3424
# Testing split: Feature index 9, Feature value 0.48, Gini = 0.3428
# Testing split: Feature index 9, Feature value 0.55, Gini = 0.3263
# Testing split: Feature index 9, Feature value 0.44, Gini = 0.3477
# Testing split: Feature index 9, Feature value 0.64, Gini = 0.3349
# Testing split: Feature index 9, Feature value 0.62, Gini = 0.3508
# Testing split: Feature index 9, Feature value 0.49, Gini = 0.3481
# Testing split: Feature index 9, Feature value 0.51, Gini = 0.3512
# Testing split: Feature index 9, Feature value 0.5, Gini = 0.3506
# Testing split: Feature index 9, Feature value 0.43, Gini = 0.3463
# Testing split: Feature index 9, Feature value 0.6, Gini = 0.3428
# Testing split: Feature index 9, Feature value 0.46, Gini = 0.3508
# Testing split: Feature index 9, Feature value 0.64, Gini = 0.3349
# Testing split: Feature index 9, Feature value 0.54, Gini = 0.3424
# Testing split: Feature index 10, Feature value 11.5, Gini = 0.3477
# Testing split: Feature index 10, Feature value 11.2, Gini = 0.3512
# Testing split: Feature index 10, Feature value 10.9, Gini = 0.3337
# Testing split: Feature index 10, Feature value 10.8, Gini = 0.3364
# Testing split: Feature index 10, Feature value 10.9, Gini = 0.3337
# Testing split: Feature index 10, Feature value 10.8, Gini = 0.3364
# Testing split: Feature index 10, Feature value 10.9, Gini = 0.3337
# Testing split: Feature index 10, Feature value 10.7, Gini = 0.3512
# Testing split: Feature index 10, Feature value 11.1, Gini = 0.3500
# Testing split: Feature index 10, Feature value 10.9, Gini = 0.3337
# Testing split: Feature index 10, Feature value 11.2, Gini = 0.3512
# Testing split: Feature index 10, Feature value 10.9, Gini = 0.3337
# Testing split: Feature index 10, Feature value 10.9, Gini = 0.3337
# Testing split: Feature index 10, Feature value 11.5, Gini = 0.3477
# Testing split: Feature index 10, Feature value 10.9, Gini = 0.3337
# Testing split: Feature index 10, Feature value 10.8, Gini = 0.3364
# Testing split: Feature index 10, Feature value 11.2, Gini = 0.3512
# Testing split: Feature index 10, Feature value 11.4, Gini = 0.3510
# Testing split: Feature index 10, Feature value 11.5, Gini = 0.3477
# Testing split: Feature index 10, Feature value 11.2, Gini = 0.3512
# Testing split: Feature index 10, Feature value 11.3, Gini = 0.3508
# Testing split: Feature index 10, Feature value 10.7, Gini = 0.3512
#
# Best split: Feature index 4, Feature value 0.07, Gini = 0.2273
#
# Testing split: Feature index 0, Feature value 8.9, Gini = 0.0000
# Testing split: Feature index 0, Feature value 9.8, Gini = 0.0000
# Testing split: Feature index 0, Feature value 6.4, Gini = 0.0000
# Testing split: Feature index 0, Feature value 7.6, Gini = 0.0000
# Testing split: Feature index 0, Feature value 6.8, Gini = 0.0000
# Testing split: Feature index 0, Feature value 8.1, Gini = 0.0000
# Testing split: Feature index 0, Feature value 6.3, Gini = 0.0000
# Testing split: Feature index 0, Feature value 8.2, Gini = 0.0000
# Testing split: Feature index 0, Feature value 6.5, Gini = 0.0000
# Testing split: Feature index 0, Feature value 6.5, Gini = 0.0000
# Testing split: Feature index 0, Feature value 10.1, Gini = 0.0000
# Testing split: Feature index 0, Feature value 7.4, Gini = 0.0000
# Testing split: Feature index 1, Feature value 0.875, Gini = 0.0000
# Testing split: Feature index 1, Feature value 0.88, Gini = 0.0000
# Testing split: Feature index 1, Feature value 0.885, Gini = 0.0000
# Testing split: Feature index 1, Feature value 1.58, Gini = 0.0000
# Testing split: Feature index 1, Feature value 0.915, Gini = 0.0000
# Testing split: Feature index 1, Feature value 1.33, Gini = 0.0000
# Testing split: Feature index 1, Feature value 1.02, Gini = 0.0000
# Testing split: Feature index 1, Feature value 1.33, Gini = 0.0000
# Testing split: Feature index 1, Feature value 0.885, Gini = 0.0000
# Testing split: Feature index 1, Feature value 0.88, Gini = 0.0000
# Testing split: Feature index 1, Feature value 0.935, Gini = 0.0000
# Testing split: Feature index 1, Feature value 1.185, Gini = 0.0000
# Testing split: Feature index 2, Feature value 0.13, Gini = 0.0000
# Testing split: Feature index 2, Feature value 0.25, Gini = 0.0000
# Testing split: Feature index 2, Feature value 0.0, Gini = 0.0000
# Testing split: Feature index 2, Feature value 0.0, Gini = 0.0000
# Testing split: Feature index 2, Feature value 0.29, Gini = 0.0000
# Testing split: Feature index 2, Feature value 0.0, Gini = 0.0000
# Testing split: Feature index 2, Feature value 0.0, Gini = 0.0000
# Testing split: Feature index 2, Feature value 0.0, Gini = 0.0000
# Testing split: Feature index 2, Feature value 0.0, Gini = 0.0000
# Testing split: Feature index 2, Feature value 0.03, Gini = 0.0000
# Testing split: Feature index 2, Feature value 0.22, Gini = 0.0000
# Testing split: Feature index 2, Feature value 0.0, Gini = 0.0000
# Testing split: Feature index 3, Feature value 3.45, Gini = 0.0000
# Testing split: Feature index 3, Feature value 2.5, Gini = 0.0000
# Testing split: Feature index 3, Feature value 2.3, Gini = 0.0000
# Testing split: Feature index 3, Feature value 2.1, Gini = 0.0000
# Testing split: Feature index 3, Feature value 4.8, Gini = 0.0000
# Testing split: Feature index 3, Feature value 1.8, Gini = 0.0000
# Testing split: Feature index 3, Feature value 2.0, Gini = 0.0000
# Testing split: Feature index 3, Feature value 1.7, Gini = 0.0000
# Testing split: Feature index 3, Feature value 2.3, Gini = 0.0000
# Testing split: Feature index 3, Feature value 5.6, Gini = 0.0000
# Testing split: Feature index 3, Feature value 3.4, Gini = 0.0000
# Testing split: Feature index 3, Feature value 4.25, Gini = 0.0000
# Testing split: Feature index 4, Feature value 0.088, Gini = 0.0000
# Testing split: Feature index 4, Feature value 0.104, Gini = 0.0000
# Testing split: Feature index 4, Feature value 0.166, Gini = 0.0000
# Testing split: Feature index 4, Feature value 0.137, Gini = 0.0000
# Testing split: Feature index 4, Feature value 0.07, Gini = 0.0000
# Testing split: Feature index 4, Feature value 0.082, Gini = 0.0000
# Testing split: Feature index 4, Feature value 0.083, Gini = 0.0000
# Testing split: Feature index 4, Feature value 0.081, Gini = 0.0000
# Testing split: Feature index 4, Feature value 0.166, Gini = 0.0000
# Testing split: Feature index 4, Feature value 0.079, Gini = 0.0000
# Testing split: Feature index 4, Feature value 0.105, Gini = 0.0000
# Testing split: Feature index 4, Feature value 0.097, Gini = 0.0000
# Testing split: Feature index 5, Feature value 4.0, Gini = 0.0000
# Testing split: Feature index 5, Feature value 35.0, Gini = 0.0000
# Testing split: Feature index 5, Feature value 6.0, Gini = 0.0000
# Testing split: Feature index 5, Feature value 5.0, Gini = 0.0000
# Testing split: Feature index 5, Feature value 15.0, Gini = 0.0000
# Testing split: Feature index 5, Feature value 3.0, Gini = 0.0000
# Testing split: Feature index 5, Feature value 17.0, Gini = 0.0000
# Testing split: Feature index 5, Feature value 3.0, Gini = 0.0000
# Testing split: Feature index 5, Feature value 6.0, Gini = 0.0000
# Testing split: Feature index 5, Feature value 23.0, Gini = 0.0000
# Testing split: Feature index 5, Feature value 11.0, Gini = 0.0000
# Testing split: Feature index 5, Feature value 5.0, Gini = 0.0000
# Testing split: Feature index 6, Feature value 14.0, Gini = 0.0000
# Testing split: Feature index 6, Feature value 155.0, Gini = 0.0000
# Testing split: Feature index 6, Feature value 12.0, Gini = 0.0000
# Testing split: Feature index 6, Feature value 9.0, Gini = 0.0000
# Testing split: Feature index 6, Feature value 39.0, Gini = 0.0000
# Testing split: Feature index 6, Feature value 12.0, Gini = 0.0000
# Testing split: Feature index 6, Feature value 24.0, Gini = 0.0000
# Testing split: Feature index 6, Feature value 12.0, Gini = 0.0000
# Testing split: Feature index 6, Feature value 12.0, Gini = 0.0000
# Testing split: Feature index 6, Feature value 47.0, Gini = 0.0000
# Testing split: Feature index 6, Feature value 86.0, Gini = 0.0000
# Testing split: Feature index 6, Feature value 14.0, Gini = 0.0000
# Testing split: Feature index 7, Feature value 0.9994, Gini = 0.0000
# Testing split: Feature index 7, Feature value 1.001, Gini = 0.0000
# Testing split: Feature index 7, Feature value 0.99551, Gini = 0.0000
# Testing split: Feature index 7, Feature value 0.99476, Gini = 0.0000
# Testing split: Feature index 7, Feature value 0.99577, Gini = 0.0000
# Testing split: Feature index 7, Feature value 0.9964, Gini = 0.0000
# Testing split: Feature index 7, Feature value 0.99437, Gini = 0.0000
# Testing split: Feature index 7, Feature value 0.9964, Gini = 0.0000
# Testing split: Feature index 7, Feature value 0.99551, Gini = 0.0000
# Testing split: Feature index 7, Feature value 0.99572, Gini = 0.0000
# Testing split: Feature index 7, Feature value 1.001, Gini = 0.0000
# Testing split: Feature index 7, Feature value 0.9966, Gini = 0.0000
# Testing split: Feature index 8, Feature value 3.44, Gini = 0.0000
# Testing split: Feature index 8, Feature value 3.41, Gini = 0.0000
# Testing split: Feature index 8, Feature value 3.56, Gini = 0.0000
# Testing split: Feature index 8, Feature value 3.5, Gini = 0.0000
# Testing split: Feature index 8, Feature value 3.53, Gini = 0.0000
# Testing split: Feature index 8, Feature value 3.54, Gini = 0.0000
# Testing split: Feature index 8, Feature value 3.59, Gini = 0.0000
# Testing split: Feature index 8, Feature value 3.53, Gini = 0.0000
# Testing split: Feature index 8, Feature value 3.56, Gini = 0.0000
# Testing split: Feature index 8, Feature value 3.58, Gini = 0.0000
# Testing split: Feature index 8, Feature value 3.43, Gini = 0.0000
# Testing split: Feature index 8, Feature value 3.63, Gini = 0.0000
# Testing split: Feature index 9, Feature value 0.52, Gini = 0.0000
# Testing split: Feature index 9, Feature value 0.67, Gini = 0.0000
# Testing split: Feature index 9, Feature value 0.51, Gini = 0.0000
# Testing split: Feature index 9, Feature value 0.4, Gini = 0.0000
# Testing split: Feature index 9, Feature value 0.54, Gini = 0.0000
# Testing split: Feature index 9, Feature value 0.48, Gini = 0.0000
# Testing split: Feature index 9, Feature value 0.55, Gini = 0.0000
# Testing split: Feature index 9, Feature value 0.49, Gini = 0.0000
# Testing split: Feature index 9, Feature value 0.51, Gini = 0.0000
# Testing split: Feature index 9, Feature value 0.5, Gini = 0.0000
# Testing split: Feature index 9, Feature value 0.64, Gini = 0.0000
# Testing split: Feature index 9, Feature value 0.54, Gini = 0.0000
# Testing split: Feature index 10, Feature value 11.5, Gini = 0.0000
# Testing split: Feature index 10, Feature value 11.2, Gini = 0.0000
# Testing split: Feature index 10, Feature value 10.8, Gini = 0.0000
# Testing split: Feature index 10, Feature value 10.9, Gini = 0.0000
# Testing split: Feature index 10, Feature value 11.1, Gini = 0.0000
# Testing split: Feature index 10, Feature value 10.9, Gini = 0.0000
# Testing split: Feature index 10, Feature value 11.2, Gini = 0.0000
# Testing split: Feature index 10, Feature value 10.9, Gini = 0.0000
# Testing split: Feature index 10, Feature value 10.8, Gini = 0.0000
# Testing split: Feature index 10, Feature value 11.2, Gini = 0.0000
# Testing split: Feature index 10, Feature value 11.3, Gini = 0.0000
# Testing split: Feature index 10, Feature value 10.7, Gini = 0.0000
#
# Best split: Feature index 0, Feature value 8.9, Gini = 0.0000
#
# CART Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.76      0.72       223
#            1       0.77      0.70      0.73       257
#
#     accuracy                           0.72       480
#    macro avg       0.73      0.73      0.72       480
# weighted avg       0.73      0.72      0.73       480

# %%
print("CART Accuracy:", cart_accuracy)

print("CART Classification Report:\n", classification_report(y_test, cart_predictions))
# Out:
# CART Accuracy: 0.725
# CART Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.76      0.72       223
#            1       0.77      0.70      0.73       257
#
#     accuracy                           0.72       480
#    macro avg       0.73      0.73      0.72       480
# weighted avg       0.73      0.72      0.73       480

# %% [markdown]
# ID3 & C4.5

# %%
id3_model = DecisionTreeClassifier(criterion='entropy', max_depth=5)
id3_model.fit(X_train, y_train)
id3_predictions = id3_model.predict(X_test)
id3_accuracy = accuracy_score(y_test, id3_predictions)
print("ID3 Accuracy:", id3_accuracy)
print("ID3 Classification Report:\n", classification_report(y_test, id3_predictions))
# Out:
# ID3 Accuracy: 0.7229166666666667
# ID3 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.78      0.72       223
#            1       0.78      0.68      0.72       257
#
#     accuracy                           0.72       480
#    macro avg       0.73      0.73      0.72       480
# weighted avg       0.73      0.72      0.72       480

# %%
c45_model = DecisionTreeClassifier(criterion='entropy', max_depth=5)
c45_model.fit(X_train, y_train)
c45_predictions = c45_model.predict(X_test)
c45_accuracy = accuracy_score(y_test, c45_predictions)
print("C4.5 Accuracy:", c45_accuracy)
print("C4.5 Classification Report:\n", classification_report(y_test, c45_predictions))
# Out:
# C4.5 Accuracy: 0.725
# C4.5 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.68      0.78      0.72       223
#            1       0.78      0.68      0.73       257
#
#     accuracy                           0.72       480
#    macro avg       0.73      0.73      0.72       480
# weighted avg       0.73      0.72      0.73       480

# %%
print(f"\nComparison of Accuracy:\nCART: {cart_accuracy}\nID3: {id3_accuracy}\nC4.5: {c45_accuracy}")
# Out:
# Comparison of Accuracy:
# CART: 0.725
# ID3: 0.7229166666666667
# C4.5: 0.725
